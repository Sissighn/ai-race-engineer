# %%
import sys, os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

project_root
# Out:
# '/Users/setayesh/Desktop/projects/python_projects/ai-race-engineer'

# %%
import pandas as pd

from src.data.load_data import load_session
from src.data.compare import compare_drivers_corner_level
from src.insights.time_loss_engine import estimate_time_loss_per_corner
from src.insights.coaching_engine import coaching_suggestions
# Out:
# /Users/setayesh/Desktop/projects/python_projects/ai-race-engineer/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 6
#       4 from src.data.compare import compare_drivers_corner_level
#       5 from src.insights.time_loss_engine import estimate_time_loss_per_corner
# ----> 6 from src.insights.coaching_engine import coaching_suggestions
#
# ImportError: cannot import name 'coaching_suggestions' from 'src.insights.coaching_engine' (/Users/setayesh/Desktop/projects/python_projects/ai-race-engineer/src/insights/coaching_engine.py)

# %%
session = load_session(2023, "Silverstone", "Q")
comp = compare_drivers_corner_level(session, "VER", "PER")
tl = estimate_time_loss_per_corner(comp, "VER", "PER")
tl

# %%
suggest = coaching_suggestions(tl, "VER", "PER")

for s in suggest:
    print("•", s)
