# %%
import os
import sys
from pathlib import Path

outputs
# Out:
# Working dir: /Users/setayesh/Desktop/projects/python_projects/ai-race-engineer/notebooks
# Project root: /Users/setayesh/Desktop/projects/python_projects/ai-race-engineer
